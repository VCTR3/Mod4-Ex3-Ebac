# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests
# Out:
# C:\Users\Victor Hugo\AppData\Local\Temp\ipykernel_5176\1058106858.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'
r = requests.get(url)
data_json = r.json()
df = pd.DataFrame(data_json['items'])
df_RJ = df.loc[df['uf'].str.contains('RJ')]
df_RJ
# Out:
#       id_pleito tipo_interessado          interessado  cod_ibge  uf  \
# 453        5714        Município         Silva Jardim   3305604  RJ
# 601       66228        Município  São Pedro da Aldeia   3305208  RJ
# 824       34099        Município              Resende   3304201  RJ
# 836       65407        Município             Itaboraí   3301900  RJ
# 869       61653        Município          Teresópolis   3305802  RJ
# ...         ...              ...                  ...       ...  ..
# 4536      13036        Município              Niterói   3303302  RJ
# 4600      10315        Município       Rio de Janeiro   3304557  RJ
# 4612      13364           Estado       Rio de Janeiro        33  RJ
# 4811      11690        Município               Tanguá   3305752  RJ
# 4955      27100        Município       Rio de Janeiro   3304557  RJ
#
#                    num_pvl                                             status  \
# 453                   None                                          Arquivado
# 601   PVL02.003177/2023-42                                  Deferido (PVL-IF)
# 824   PVL02.003090/2019-99                                  Deferido (PVL-IF)
# 836   PVL02.001946/2023-78                                 Arquivado a pedido
# 869   PVL02.007127/2022-53                                           Deferido
# ...                    ...                                                ...
# 4536                  None                                       Regularizado
# 4600                  None                                           Deferido
# 4612                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4811                  None                                          Arquivado
# 4955  PVL02.002429/2017-78                     Arquivado por decurso de prazo
#
#               num_processo        data_protocolo  \
# 453   17944.000180/2008-38  2008-05-14T03:00:00Z
# 601                   None                  None
# 824                   None                  None
# 836   17944.102785/2023-00  2023-06-30T18:15:09Z
# 869   17944.103775/2022-01  2022-10-19T19:18:08Z
# ...                    ...                   ...
# 4536  17944.001891/2006-68  2006-12-30T02:00:00Z
# 4600  17944.001169/2005-42  2007-04-30T03:00:00Z
# 4612  17944.002059/2008-41  2009-05-14T03:00:00Z
# 4811  17944.001503/2008-19  2008-11-04T02:00:00Z
# 4955  17944.103668/2017-15  2018-07-31T21:50:09Z
#
#                                           tipo_operacao  \
# 453                         Operação contratual interna
# 601                         Operação contratual interna
# 824                         Operação contratual interna
# 836                         Operação contratual interna
# 869                         Operação contratual interna
# ...                                                 ...
# 4536                        Operação contratual interna
# 4600                        Operação contratual interna
# 4612  Operação contratual externa (com garantia da U...
# 4811                        Operação contratual interna
# 4955                        Operação contratual interna
#
#                                       finalidade  \
# 453                            Caminho da Escola
# 601                               Infraestrutura
# 824                            Aporte de capital
# 836                               Infraestrutura
# 869                               Multissetorial
# ...                                          ...
# 4536  Regularização de Dívida - Energia Elétrica
# 4600                                       RELUZ
# 4612                              Infraestrutura
# 4811                                       PNAFM
# 4955                              Infraestrutura
#
#                                tipo_credor  \
# 453        Instituição Financeira Nacional
# 601        Instituição Financeira Nacional
# 824        Instituição Financeira Nacional
# 836        Instituição Financeira Nacional
# 869        Instituição Financeira Nacional
# ...                                    ...
# 4536                       Empresa Estatal
# 4600                   Empresa Não Estatal
# 4612  Instituição Financeira Internacional
# 4811       Instituição Financeira Nacional
# 4955       Instituição Financeira Nacional
#
#                                                  credor          moeda  \
# 453                                 Banco do Brasil S/A           Real
# 601                                 Banco do Brasil S/A           Real
# 824                             Caixa Econômica Federal           Real
# 836                             Caixa Econômica Federal           Real
# 869      Agência de Fomento do Estado do Rio de Janeiro           Real
# ...                                                 ...            ...
# 4536        Companhia de Eletricidade do Rio de Janeiro           Real
# 4600               Light - Serviços de Eletricidade S/A           Real
# 4612  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 4811                            Caixa Econômica Federal           Real
# 4955                            Caixa Econômica Federal           Real
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 453   4.831600e+05                 0                      0  15/05/2008
# 601   5.500000e+06                 0                      1  12/09/2023
# 824   4.500000e+06                 0                      1  27/09/2019
# 836   1.000000e+08                 0                      0  05/10/2023
# 869   3.500000e+07                 0                      0  21/10/2022
# ...            ...               ...                    ...         ...
# 4536  4.146836e+06                 0                      0  12/01/2007
# 4600  3.006194e+07                 1                      0  25/05/2007
# 4612  2.117000e+08                 1                      0  22/05/2009
# 4811  3.003810e+05                 0                      0  06/02/2009
# 4955  1.000000e+08                 0                      0  07/01/2019
#
# [79 rows x 18 columns]

# %%
status_counts = df['status'].value_counts()

top3_statuses = status_counts.head(3)
print("Três status mais frequentes:")
print(top3_statuses)

# %%
df['data_status'] = df['data_status'].astype(str)
df['ano_status'] = df['data_status'].str.slice(6, 10)
df

# %%
ano_counts = df['ano_status'].value_counts()
ano_counts

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
df_tipo_interessado_counts = df['tipo_interessado'].value_counts().reset_index()
df_tipo_interessado_counts
# Out:
#   tipo_interessado  count
# 0        Município   4734
# 1           Estado    266

# %%
df_MG = df.loc[df['uf'].str.contains('MG') & df['status'].str.contains('Arquivado por decurso de prazo')]
num_solicitacoes_MG = df_MG.shape[0]
num_solicitacoes_MG
# Out:
# 73

# %%
df_BA = df.loc[(df['uf'].str.contains('BA')) & (df['status'].str.contains('Deferido')) & (df['tipo_interessado'] == 'Município')]
df_BA['interessado'].value_counts().reset_index()
# Out:
#             interessado  count
# 0   Teixeira de Freitas      4
# 1         Campo Formoso      3
# 2      Lauro de Freitas      3
# 3    Riachão do Jacuípe      3
# 4   São Félix do Coribe      3
# ..                  ...    ...
# 85             Jacaraci      1
# 86        São Desidério      1
# 87     Amélia Rodrigues      1
# 88            Pindobaçu      1
# 89                Gandu      1
#
# [90 rows x 2 columns]

# %%
df_bahia_estado = df[(df['uf'].str.strip() == 'BA') & (df['tipo_interessado'] == 'Estado')]
df_bahia_estado.to_csv('bahia_estado_solicitacoes.csv', index=False)
