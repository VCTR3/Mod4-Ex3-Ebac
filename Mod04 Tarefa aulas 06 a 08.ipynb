# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'
r = requests.get(url)
data_json = r.json()
df = pd.DataFrame(data_json['items'])
df_RJ = df.loc[df['uf'].str.contains('RJ')]
df

# %%
status_counts = df['status'].value_counts()

top3_statuses = status_counts.head(3)
print("Três status mais frequentes:")
print(top3_statuses)

# %%
import pandas as pd

df['data_status'] = df['data_status'].astype(str)
df['ano_status'] = df['data_status'].str.slice(6, 10)
df

# %%
ano_counts = df['ano_status'].value_counts()
ano_counts

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
df_tipo_interessado_counts = df['tipo_interessado'].value_counts().reset_index()
df_tipo_interessado_counts
# Out:
#   tipo_interessado  count
# 0        Município   4754
# 1           Estado    246

# %%
df_MG = df.loc[df['uf'].str.contains('MG') & df['status'].str.contains('Arquivado por decurso de prazo')]
df_MG
# Out:
#       id_pleito tipo_interessado         interessado  cod_ibge  uf  \
# 29        45308        Município           Tarumirim   3168408  MG
# 46        39272        Município          Nova Belém   3144672  MG
# 168       61470        Município  Ribeirão das Neves   3154606  MG
# 169       39306        Município     Mendes Pimentel   3141504  MG
# 534       64918        Município              Frutal   3127107  MG
# ...         ...              ...                 ...       ...  ..
# 4394      11443        Município            Taparuba   3168051  MG
# 4426       5402        Município         Bias Fortes   3106804  MG
# 4635      12923        Município           Belo Vale   3106408  MG
# 4637      13064        Município     Bandeira do Sul   3105301  MG
# 4719      22157        Município           Jacutinga   3134905  MG
#
#                    num_pvl                                   status  \
# 29    PVL02.001490/2021-84  Arquivado por decurso de prazo (PVL-IF)
# 46    PVL02.007943/2019-61  Arquivado por decurso de prazo (PVL-IF)
# 168   PVL02.007542/2022-15           Arquivado por decurso de prazo
# 169   PVL02.007977/2019-56  Arquivado por decurso de prazo (PVL-IF)
# 534   PVL02.006121/2022-69           Arquivado por decurso de prazo
# ...                    ...                                      ...
# 4394                  None           Arquivado por decurso de prazo
# 4426                  None           Arquivado por decurso de prazo
# 4635                  None           Arquivado por decurso de prazo
# 4637                  None           Arquivado por decurso de prazo
# 4719  00000.000000/2030-31           Arquivado por decurso de prazo
#
#               num_processo        data_protocolo                tipo_operacao  \
# 29                    None                  None  Operação contratual interna
# 46                    None                  None  Operação contratual interna
# 168   17944.103572/2022-14  2022-08-31T12:29:27Z  Operação contratual interna
# 169                   None                  None  Operação contratual interna
# 534   17944.102330/2023-86  2023-08-17T15:09:11Z  Operação contratual interna
# ...                    ...                   ...                          ...
# 4394  17944.001449/2010-18  2010-11-17T02:00:00Z  Operação contratual interna
# 4426  17944.000105/2012-53  2012-04-27T03:00:00Z  Operação contratual interna
# 4635  17944.001851/2011-83  2012-03-15T03:00:00Z  Operação contratual interna
# 4637  17944.001900/2013-40  2013-11-21T02:00:00Z  Operação contratual interna
# 4719  17944.000456/2016-98  2016-04-01T03:00:00Z  Operação contratual interna
#
#                                              finalidade  \
# 29                                       Infraestrutura
# 46    Aquisição de terrenos, imóveis e/ou construção...
# 168                                      Multissetorial
# 169   Aquisição de terrenos, imóveis e/ou construção...
# 534                                      Infraestrutura
# ...                                                 ...
# 4394     Aquisição de máquinas, equipamentos e veículos
# 4426                                     Infraestrutura
# 4635                                       Provias 2010
# 4637                                  Caminho da Escola
# 4719                                  Saneamento básico
#
#                           tipo_credor  \
# 29    Instituição Financeira Nacional
# 46    Instituição Financeira Nacional
# 168   Instituição Financeira Nacional
# 169   Instituição Financeira Nacional
# 534   Instituição Financeira Nacional
# ...                               ...
# 4394  Instituição Financeira Nacional
# 4426  Instituição Financeira Nacional
# 4635  Instituição Financeira Nacional
# 4637  Instituição Financeira Nacional
# 4719  Instituição Financeira Nacional
#
#                                             credor moeda       valor  \
# 29    Banco de Desenvolvimento de Minas Gerais S/A  Real    800000.0
# 46    Banco de Desenvolvimento de Minas Gerais S/A  Real   1000000.0
# 168   Banco de Desenvolvimento de Minas Gerais S/A  Real   6000000.0
# 169   Banco de Desenvolvimento de Minas Gerais S/A  Real    500000.0
# 534                        Caixa Econômica Federal  Real  20000000.0
# ...                                            ...   ...         ...
# 4394  Banco de Desenvolvimento de Minas Gerais S/A  Real    310000.0
# 4426  Banco de Desenvolvimento de Minas Gerais S/A  Real    492000.0
# 4635  Banco de Desenvolvimento de Minas Gerais S/A  Real    627000.0
# 4637                           Banco do Brasil S/A  Real    278000.0
# 4719  Banco de Desenvolvimento de Minas Gerais S/A  Real    800000.0
#
#       pvl_assoc_divida  pvl_contradado_credor data_status
# 29                   0                      0  03/04/2023
# 46                   0                      0  30/03/2023
# 168                  0                      0  10/02/2023
# 169                  0                      0  10/03/2023
# 534                  0                      0  11/12/2023
# ...                ...                    ...         ...
# 4394                 0                      0  24/08/2012
# 4426                 0                      0  29/06/2012
# 4635                 0                      0  28/01/2013
# 4637                 0                      0  16/10/2014
# 4719                 0                      0  11/10/2016
#
# [70 rows x 18 columns]

# %%
df_BA = df.loc[(df['uf'].str.contains('BA')) & (df['status'].str.contains('Deferido')) & (df['tipo_interessado'] == 'Município')]
df_BA['interessado'].value_counts().reset_index()
# Out:
#                interessado  count
# 0        Bom Jesus da Lapa      4
# 1                 Amargosa      3
# 2                Barreiras      3
# 3   Luís Eduardo Magalhães      3
# 4      Teixeira de Freitas      3
# ..                     ...    ...
# 89               Andorinha      1
# 90      Boa Vista do Tupim      1
# 91    Palmas de Monte Alto      1
# 92               Jaguarari      1
# 93                 Guajeru      1
#
# [94 rows x 2 columns]

# %%
df_bahia_estado = df[(df['uf'].str.strip() == 'BA')]
df_bahia_estado.to_csv('bahia_estado_solicitacoes.csv', index=False)
